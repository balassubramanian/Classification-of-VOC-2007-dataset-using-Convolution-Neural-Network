# %% [markdown]
# # Assignment 2 Part 2: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/gdrive/My Drive/CS747_Assignment2')

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier #AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %% [markdown]
# # Part 2: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('/content/gdrive/My Drive/CS747_Assignment2/VOCdevkit_2007/VOC2007/','train',train_transform)
ds_val = VocDataset('/content/gdrive/My Drive/CS747_Assignment2/VOCdevkit_2007/VOC2007/','val',test_transform)
ds_test = VocDataset('/content/gdrive/My Drive/CS747_Assignment2/VOCdevkit_2007/VOC2007test/','test', test_transform)
# Out:
# /content/gdrive/My Drive/CS747_Assignment2/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(box_indices),

# %%
num_epochs = 100
test_frequency = 5
batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier #AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of classifier failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 844, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 980, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1038, in get_data
# FileNotFoundError: [Errno 2] No such file or directory
# ]

# %%
classifier = Classifier().to(device)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
#optimizer = torch.optim.Adagrad(classifier.parameters(), lr=0.005, lr_decay=0, weight_decay=0.005)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.005,  weight_decay = 0.005, momentum=0.9,nesterov=False)
#optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)
#scheduler.step()
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.28238150477409363
# -------  Class: aeroplane        AP:   0.2750  -------
# -------  Class: bicycle          AP:   0.0807  -------
# -------  Class: bird             AP:   0.0891  -------
# -------  Class: boat             AP:   0.0964  -------
# -------  Class: bottle           AP:   0.0723  -------
# -------  Class: bus              AP:   0.0737  -------
# -------  Class: car              AP:   0.2066  -------
# -------  Class: cat              AP:   0.0889  -------
# -------  Class: chair            AP:   0.1959  -------
# -------  Class: cow              AP:   0.0327  -------
# -------  Class: diningtable      AP:   0.1272  -------
# -------  Class: dog              AP:   0.1158  -------
# -------  Class: horse            AP:   0.0819  -------
# -------  Class: motorbike        AP:   0.0712  -------
# -------  Class: person           AP:   0.5032  -------
# -------  Class: pottedplant      AP:   0.0862  -------
# -------  Class: sheep            AP:   0.0284  -------
# -------  Class: sofa             AP:   0.1498  -------
# -------  Class: train            AP:   0.1886  -------
# -------  Class: tvmonitor        AP:   0.0847  -------
# mAP: 0.1324
# Avg loss: 0.24512261413037778
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.13242208360933588
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2363341897726059
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2258027046918869
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.21605496108531952
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.21209287643432617
# -------  Class: aeroplane        AP:   0.3829  -------
# -------  Class: bicycle          AP:   0.1442  -------
# -------  Class: bird             AP:   0.1623  -------
# -------  Class: boat             AP:   0.3179  -------
# -------  Class: bottle           AP:   0.0975  -------
# -------  Class: bus              AP:   0.1369  -------
# -------  Class: car              AP:   0.3680  -------
# -------  Class: cat              AP:   0.2099  -------
# -------  Class: chair            AP:   0.2913  -------
# -------  Class: cow              AP:   0.0881  -------
# -------  Class: diningtable      AP:   0.2060  -------
# -------  Class: dog              AP:   0.1654  -------
# -------  Class: horse            AP:   0.2699  -------
# -------  Class: motorbike        AP:   0.1617  -------
# -------  Class: person           AP:   0.5693  -------
# -------  Class: pottedplant      AP:   0.1462  -------
# -------  Class: sheep            AP:   0.0948  -------
# -------  Class: sofa             AP:   0.2279  -------
# -------  Class: train            AP:   0.2597  -------
# -------  Class: tvmonitor        AP:   0.1465  -------
# mAP: 0.2223
# Avg loss: 0.21204777397215366
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.22231554640769904
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.20852303504943848
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.20175538957118988
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.1973874717950821
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.19232961535453796
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.187398299574852
# -------  Class: aeroplane        AP:   0.4503  -------
# -------  Class: bicycle          AP:   0.2220  -------
# -------  Class: bird             AP:   0.1678  -------
# -------  Class: boat             AP:   0.3453  -------
# -------  Class: bottle           AP:   0.1296  -------
# -------  Class: bus              AP:   0.1889  -------
# -------  Class: car              AP:   0.4872  -------
# -------  Class: cat              AP:   0.2700  -------
# -------  Class: chair            AP:   0.3161  -------
# -------  Class: cow              AP:   0.1064  -------
# -------  Class: diningtable      AP:   0.2569  -------
# -------  Class: dog              AP:   0.1876  -------
# -------  Class: horse            AP:   0.3613  -------
# -------  Class: motorbike        AP:   0.2221  -------
# -------  Class: person           AP:   0.6258  -------
# -------  Class: pottedplant      AP:   0.1481  -------
# -------  Class: sheep            AP:   0.1307  -------
# -------  Class: sofa             AP:   0.2712  -------
# -------  Class: train            AP:   0.3292  -------
# -------  Class: tvmonitor        AP:   0.1908  -------
# mAP: 0.2704
# Avg loss: 0.20413572303950786
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.2703650383429267
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.182632714509964
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.17843201756477356
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.17540466785430908
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.1707962602376938
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.16473889350891113
# -------  Class: aeroplane        AP:   0.5108  -------
# -------  Class: bicycle          AP:   0.2979  -------
# -------  Class: bird             AP:   0.1726  -------
# -------  Class: boat             AP:   0.3559  -------
# -------  Class: bottle           AP:   0.1321  -------
# -------  Class: bus              AP:   0.1783  -------
# -------  Class: car              AP:   0.5368  -------
# -------  Class: cat              AP:   0.2958  -------
# -------  Class: chair            AP:   0.3492  -------
# -------  Class: cow              AP:   0.1177  -------
# -------  Class: diningtable      AP:   0.2585  -------
# -------  Class: dog              AP:   0.2172  -------
# -------  Class: horse            AP:   0.4356  -------
# -------  Class: motorbike        AP:   0.3287  -------
# -------  Class: person           AP:   0.6685  -------
# -------  Class: pottedplant      AP:   0.1377  -------
# -------  Class: sheep            AP:   0.1402  -------
# -------  Class: sofa             AP:   0.2869  -------
# -------  Class: train            AP:   0.4095  -------
# -------  Class: tvmonitor        AP:   0.2288  -------
# mAP: 0.3029
# Avg loss: 0.1940549097955227
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.302931315784287
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.1588354855775833
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.15797971189022064
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.15093955397605896
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.1425100564956665
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1373562067747116
# -------  Class: aeroplane        AP:   0.5421  -------
# -------  Class: bicycle          AP:   0.3012  -------
# -------  Class: bird             AP:   0.1782  -------
# -------  Class: boat             AP:   0.4019  -------
# -------  Class: bottle           AP:   0.1296  -------
# -------  Class: bus              AP:   0.1734  -------
# -------  Class: car              AP:   0.5273  -------
# -------  Class: cat              AP:   0.3076  -------
# -------  Class: chair            AP:   0.3329  -------
# -------  Class: cow              AP:   0.1270  -------
# -------  Class: diningtable      AP:   0.3016  -------
# -------  Class: dog              AP:   0.2215  -------
# -------  Class: horse            AP:   0.4396  -------
# -------  Class: motorbike        AP:   0.3184  -------
# -------  Class: person           AP:   0.6839  -------
# -------  Class: pottedplant      AP:   0.1551  -------
# -------  Class: sheep            AP:   0.1348  -------
# -------  Class: sofa             AP:   0.2656  -------
# -------  Class: train            AP:   0.4260  -------
# -------  Class: tvmonitor        AP:   0.2500  -------
# mAP: 0.3109
# Avg loss: 0.19714040234684943
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.3108760735243545
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.13283947110176086
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.1257491558790207
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.12041013687849045
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.11271832138299942
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.10670514404773712
# -------  Class: aeroplane        AP:   0.5592  -------
# -------  Class: bicycle          AP:   0.3212  -------
# -------  Class: bird             AP:   0.1904  -------
# -------  Class: boat             AP:   0.3864  -------
# -------  Class: bottle           AP:   0.1288  -------
# -------  Class: bus              AP:   0.1881  -------
# -------  Class: car              AP:   0.5174  -------
# -------  Class: cat              AP:   0.3097  -------
# -------  Class: chair            AP:   0.3222  -------
# -------  Class: cow              AP:   0.1160  -------
# -------  Class: diningtable      AP:   0.2875  -------
# -------  Class: dog              AP:   0.2280  -------
# -------  Class: horse            AP:   0.4438  -------
# -------  Class: motorbike        AP:   0.3362  -------
# -------  Class: person           AP:   0.6800  -------
# -------  Class: pottedplant      AP:   0.1656  -------
# -------  Class: sheep            AP:   0.1532  -------
# -------  Class: sofa             AP:   0.2668  -------
# -------  Class: train            AP:   0.4235  -------
# -------  Class: tvmonitor        AP:   0.2445  -------
# mAP: 0.3134
# Avg loss: 0.2094808340072632
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.31342231978194734
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.10312483459711075
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.09716906398534775
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.09078516811132431
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.08348201960325241
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.07822101563215256
# -------  Class: aeroplane        AP:   0.5621  -------
# -------  Class: bicycle          AP:   0.3179  -------
# -------  Class: bird             AP:   0.1881  -------
# -------  Class: boat             AP:   0.3824  -------
# -------  Class: bottle           AP:   0.1188  -------
# -------  Class: bus              AP:   0.1761  -------
# -------  Class: car              AP:   0.5169  -------
# -------  Class: cat              AP:   0.3005  -------
# -------  Class: chair            AP:   0.3127  -------
# -------  Class: cow              AP:   0.1403  -------
# -------  Class: diningtable      AP:   0.2895  -------
# -------  Class: dog              AP:   0.2382  -------
# -------  Class: horse            AP:   0.4531  -------
# -------  Class: motorbike        AP:   0.3401  -------
# -------  Class: person           AP:   0.6778  -------
# -------  Class: pottedplant      AP:   0.1492  -------
# -------  Class: sheep            AP:   0.1592  -------
# -------  Class: sofa             AP:   0.2623  -------
# -------  Class: train            AP:   0.4138  -------
# -------  Class: tvmonitor        AP:   0.2493  -------
# mAP: 0.3124
# Avg loss: 0.21767087951302527
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.31241406225501545
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.07355765253305435
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.0696016475558281
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.06590019166469574
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.05896519497036934
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.055226314812898636
# -------  Class: aeroplane        AP:   0.5548  -------
# -------  Class: bicycle          AP:   0.3088  -------
# -------  Class: bird             AP:   0.2103  -------
# -------  Class: boat             AP:   0.3719  -------
# -------  Class: bottle           AP:   0.1175  -------
# -------  Class: bus              AP:   0.1580  -------
# -------  Class: car              AP:   0.4913  -------
# -------  Class: cat              AP:   0.2852  -------
# -------  Class: chair            AP:   0.3181  -------
# -------  Class: cow              AP:   0.1417  -------
# -------  Class: diningtable      AP:   0.2801  -------
# -------  Class: dog              AP:   0.2200  -------
# -------  Class: horse            AP:   0.4432  -------
# -------  Class: motorbike        AP:   0.2924  -------
# -------  Class: person           AP:   0.6778  -------
# -------  Class: pottedplant      AP:   0.1427  -------
# -------  Class: sheep            AP:   0.1622  -------
# -------  Class: sofa             AP:   0.2502  -------
# -------  Class: train            AP:   0.4371  -------
# -------  Class: tvmonitor        AP:   0.2472  -------
# mAP: 0.3055
# Avg loss: 0.23533537983894348
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.3055168391143868
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.05313261225819588
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.048428725451231
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.04546719789505005
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.042814839631319046
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.04176447167992592
# -------  Class: aeroplane        AP:   0.5703  -------
# -------  Class: bicycle          AP:   0.2944  -------
# -------  Class: bird             AP:   0.1828  -------
# -------  Class: boat             AP:   0.3574  -------
# -------  Class: bottle           AP:   0.1090  -------
# -------  Class: bus              AP:   0.1554  -------
# -------  Class: car              AP:   0.4929  -------
# -------  Class: cat              AP:   0.2868  -------
# -------  Class: chair            AP:   0.3206  -------
# -------  Class: cow              AP:   0.1246  -------
# -------  Class: diningtable      AP:   0.2733  -------
# -------  Class: dog              AP:   0.2185  -------
# -------  Class: horse            AP:   0.4242  -------
# -------  Class: motorbike        AP:   0.2686  -------
# -------  Class: person           AP:   0.6668  -------
# -------  Class: pottedplant      AP:   0.1326  -------
# -------  Class: sheep            AP:   0.1664  -------
# -------  Class: sofa             AP:   0.2408  -------
# -------  Class: train            AP:   0.4299  -------
# -------  Class: tvmonitor        AP:   0.2199  -------
# mAP: 0.2968
# Avg loss: 0.2631041493266821
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.29675154006460835
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.03723109886050224
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.03815365582704544
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.03614906594157219
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.03194373473525047
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.032134607434272766
# -------  Class: aeroplane        AP:   0.5592  -------
# -------  Class: bicycle          AP:   0.2871  -------
# -------  Class: bird             AP:   0.1811  -------
# -------  Class: boat             AP:   0.3376  -------
# -------  Class: bottle           AP:   0.1168  -------
# -------  Class: bus              AP:   0.1524  -------
# -------  Class: car              AP:   0.4796  -------
# -------  Class: cat              AP:   0.2646  -------
# -------  Class: chair            AP:   0.3149  -------
# -------  Class: cow              AP:   0.1054  -------
# -------  Class: diningtable      AP:   0.2597  -------
# -------  Class: dog              AP:   0.2135  -------
# -------  Class: horse            AP:   0.4378  -------
# -------  Class: motorbike        AP:   0.2664  -------
# -------  Class: person           AP:   0.6663  -------
# -------  Class: pottedplant      AP:   0.1371  -------
# -------  Class: sheep            AP:   0.1669  -------
# -------  Class: sofa             AP:   0.2482  -------
# -------  Class: train            AP:   0.4169  -------
# -------  Class: tvmonitor        AP:   0.2290  -------
# mAP: 0.2920
# Avg loss: 0.28991025127470493
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.29201818496480525
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.031484320759773254
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.02766587771475315
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.025020772591233253
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.026375850662589073
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.02580149844288826
# -------  Class: aeroplane        AP:   0.5592  -------
# -------  Class: bicycle          AP:   0.2779  -------
# -------  Class: bird             AP:   0.1850  -------
# -------  Class: boat             AP:   0.3410  -------
# -------  Class: bottle           AP:   0.1130  -------
# -------  Class: bus              AP:   0.1400  -------
# -------  Class: car              AP:   0.4814  -------
# -------  Class: cat              AP:   0.2699  -------
# -------  Class: chair            AP:   0.3070  -------
# -------  Class: cow              AP:   0.1161  -------
# -------  Class: diningtable      AP:   0.2466  -------
# -------  Class: dog              AP:   0.2087  -------
# -------  Class: horse            AP:   0.4415  -------
# -------  Class: motorbike        AP:   0.2809  -------
# -------  Class: person           AP:   0.6700  -------
# -------  Class: pottedplant      AP:   0.1366  -------
# -------  Class: sheep            AP:   0.1593  -------
# -------  Class: sofa             AP:   0.2432  -------
# -------  Class: train            AP:   0.4402  -------
# -------  Class: tvmonitor        AP:   0.2316  -------
# mAP: 0.2925
# Avg loss: 0.30701199881732466
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.29246174441943457
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.023446714505553246
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.021355433389544487
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.020273281261324883
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.022731510922312737
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.019213920459151268
# -------  Class: aeroplane        AP:   0.5482  -------
# -------  Class: bicycle          AP:   0.2576  -------
# -------  Class: bird             AP:   0.1888  -------
# -------  Class: boat             AP:   0.3385  -------
# -------  Class: bottle           AP:   0.1118  -------
# -------  Class: bus              AP:   0.1579  -------
# -------  Class: car              AP:   0.4812  -------
# -------  Class: cat              AP:   0.2595  -------
# -------  Class: chair            AP:   0.3120  -------
# -------  Class: cow              AP:   0.1204  -------
# -------  Class: diningtable      AP:   0.2581  -------
# -------  Class: dog              AP:   0.2050  -------
# -------  Class: horse            AP:   0.4333  -------
# -------  Class: motorbike        AP:   0.2796  -------
# -------  Class: person           AP:   0.6667  -------
# -------  Class: pottedplant      AP:   0.1432  -------
# -------  Class: sheep            AP:   0.1388  -------
# -------  Class: sofa             AP:   0.2207  -------
# -------  Class: train            AP:   0.4158  -------
# -------  Class: tvmonitor        AP:   0.2138  -------
# mAP: 0.2875
# Avg loss: 0.3061570212244987
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.28753713945840564
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.017130184918642044
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.016908232122659683
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.020994050428271294
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.019858988001942635
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.018289931118488312
# -------  Class: aeroplane        AP:   0.5607  -------
# -------  Class: bicycle          AP:   0.2632  -------
# -------  Class: bird             AP:   0.1889  -------
# -------  Class: boat             AP:   0.3261  -------
# -------  Class: bottle           AP:   0.1045  -------
# -------  Class: bus              AP:   0.1535  -------
# -------  Class: car              AP:   0.4843  -------
# -------  Class: cat              AP:   0.2626  -------
# -------  Class: chair            AP:   0.2989  -------
# -------  Class: cow              AP:   0.1150  -------
# -------  Class: diningtable      AP:   0.2498  -------
# -------  Class: dog              AP:   0.1988  -------
# -------  Class: horse            AP:   0.4230  -------
# -------  Class: motorbike        AP:   0.2762  -------
# -------  Class: person           AP:   0.6576  -------
# -------  Class: pottedplant      AP:   0.1396  -------
# -------  Class: sheep            AP:   0.1227  -------
# -------  Class: sofa             AP:   0.2152  -------
# -------  Class: train            AP:   0.4466  -------
# -------  Class: tvmonitor        AP:   0.2411  -------
# mAP: 0.2864
# Avg loss: 0.34494018480181693
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.28641742466031145
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.017747804522514343
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.015146869234740734
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.01274885144084692
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.01193962525576353
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.014112225733697414
# -------  Class: aeroplane        AP:   0.5557  -------
# -------  Class: bicycle          AP:   0.2642  -------
# -------  Class: bird             AP:   0.1776  -------
# -------  Class: boat             AP:   0.3223  -------
# -------  Class: bottle           AP:   0.1020  -------
# -------  Class: bus              AP:   0.1426  -------
# -------  Class: car              AP:   0.4837  -------
# -------  Class: cat              AP:   0.2740  -------
# -------  Class: chair            AP:   0.3035  -------
# -------  Class: cow              AP:   0.1107  -------
# -------  Class: diningtable      AP:   0.2471  -------
# -------  Class: dog              AP:   0.2046  -------
# -------  Class: horse            AP:   0.4229  -------
# -------  Class: motorbike        AP:   0.2510  -------
# -------  Class: person           AP:   0.6609  -------
# -------  Class: pottedplant      AP:   0.1314  -------
# -------  Class: sheep            AP:   0.1332  -------
# -------  Class: sofa             AP:   0.2295  -------
# -------  Class: train            AP:   0.4408  -------
# -------  Class: tvmonitor        AP:   0.2321  -------
# mAP: 0.2845
# Avg loss: 0.3372052937746048
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.284486005238424
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.012314568273723125
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.011804291978478432
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.0118445148691535
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.014196877367794514
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.0115245021879673
# -------  Class: aeroplane        AP:   0.5543  -------
# -------  Class: bicycle          AP:   0.2611  -------
# -------  Class: bird             AP:   0.1928  -------
# -------  Class: boat             AP:   0.3097  -------
# -------  Class: bottle           AP:   0.1090  -------
# -------  Class: bus              AP:   0.1397  -------
# -------  Class: car              AP:   0.4791  -------
# -------  Class: cat              AP:   0.2642  -------
# -------  Class: chair            AP:   0.2970  -------
# -------  Class: cow              AP:   0.1038  -------
# -------  Class: diningtable      AP:   0.2552  -------
# -------  Class: dog              AP:   0.2057  -------
# -------  Class: horse            AP:   0.4211  -------
# -------  Class: motorbike        AP:   0.2771  -------
# -------  Class: person           AP:   0.6558  -------
# -------  Class: pottedplant      AP:   0.1212  -------
# -------  Class: sheep            AP:   0.1278  -------
# -------  Class: sofa             AP:   0.2250  -------
# -------  Class: train            AP:   0.4343  -------
# -------  Class: tvmonitor        AP:   0.2187  -------
# mAP: 0.2826
# Avg loss: 0.36899452954530715
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.2826413036634464
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.011773812584578991
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.012698101811110973
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.013145814649760723
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.01466368418186903
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.013578193262219429
# -------  Class: aeroplane        AP:   0.5454  -------
# -------  Class: bicycle          AP:   0.2340  -------
# -------  Class: bird             AP:   0.1854  -------
# -------  Class: boat             AP:   0.2975  -------
# -------  Class: bottle           AP:   0.1009  -------
# -------  Class: bus              AP:   0.1161  -------
# -------  Class: car              AP:   0.4694  -------
# -------  Class: cat              AP:   0.2735  -------
# -------  Class: chair            AP:   0.3071  -------
# -------  Class: cow              AP:   0.1120  -------
# -------  Class: diningtable      AP:   0.2764  -------
# -------  Class: dog              AP:   0.2097  -------
# -------  Class: horse            AP:   0.4357  -------
# -------  Class: motorbike        AP:   0.2681  -------
# -------  Class: person           AP:   0.6476  -------
# -------  Class: pottedplant      AP:   0.1263  -------
# -------  Class: sheep            AP:   0.1163  -------
# -------  Class: sofa             AP:   0.2284  -------
# -------  Class: train            AP:   0.4307  -------
# -------  Class: tvmonitor        AP:   0.2113  -------
# mAP: 0.2796
# Avg loss: 0.37393227145075797
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.27958730967581086
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.010695667006075382
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.009616093710064888
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.009665434248745441
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.0096363490447402
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.009518285281956196
# -------  Class: aeroplane        AP:   0.5611  -------
# -------  Class: bicycle          AP:   0.2536  -------
# -------  Class: bird             AP:   0.1766  -------
# -------  Class: boat             AP:   0.3333  -------
# -------  Class: bottle           AP:   0.1035  -------
# -------  Class: bus              AP:   0.1269  -------
# -------  Class: car              AP:   0.4699  -------
# -------  Class: cat              AP:   0.2594  -------
# -------  Class: chair            AP:   0.2997  -------
# -------  Class: cow              AP:   0.1052  -------
# -------  Class: diningtable      AP:   0.2506  -------
# -------  Class: dog              AP:   0.1963  -------
# -------  Class: horse            AP:   0.4237  -------
# -------  Class: motorbike        AP:   0.2647  -------
# -------  Class: person           AP:   0.6592  -------
# -------  Class: pottedplant      AP:   0.1247  -------
# -------  Class: sheep            AP:   0.1241  -------
# -------  Class: sofa             AP:   0.2419  -------
# -------  Class: train            AP:   0.4209  -------
# -------  Class: tvmonitor        AP:   0.2237  -------
# mAP: 0.2809
# Avg loss: 0.39508090987801553
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.28094613688351666
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.008836646564304829
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.009996498934924603
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.007977614179253578
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.009333029389381409
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.009622814133763313
# -------  Class: aeroplane        AP:   0.5521  -------
# -------  Class: bicycle          AP:   0.2127  -------
# -------  Class: bird             AP:   0.1812  -------
# -------  Class: boat             AP:   0.3038  -------
# -------  Class: bottle           AP:   0.1010  -------
# -------  Class: bus              AP:   0.1228  -------
# -------  Class: car              AP:   0.4758  -------
# -------  Class: cat              AP:   0.2592  -------
# -------  Class: chair            AP:   0.2976  -------
# -------  Class: cow              AP:   0.0946  -------
# -------  Class: diningtable      AP:   0.2629  -------
# -------  Class: dog              AP:   0.2074  -------
# -------  Class: horse            AP:   0.4203  -------
# -------  Class: motorbike        AP:   0.2675  -------
# -------  Class: person           AP:   0.6550  -------
# -------  Class: pottedplant      AP:   0.1374  -------
# -------  Class: sheep            AP:   0.1136  -------
# -------  Class: sofa             AP:   0.2278  -------
# -------  Class: train            AP:   0.4213  -------
# -------  Class: tvmonitor        AP:   0.2302  -------
# mAP: 0.2772
# Avg loss: 0.41632921174168586
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.2772093491956714
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.009808489121496677
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.008803418837487698
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.008322878740727901
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.01573236845433712
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.01029021292924881
# -------  Class: aeroplane        AP:   0.5467  -------
# -------  Class: bicycle          AP:   0.1932  -------
# -------  Class: bird             AP:   0.1770  -------
# -------  Class: boat             AP:   0.3224  -------
# -------  Class: bottle           AP:   0.1073  -------
# -------  Class: bus              AP:   0.1268  -------
# -------  Class: car              AP:   0.4715  -------
# -------  Class: cat              AP:   0.2647  -------
# -------  Class: chair            AP:   0.3077  -------
# -------  Class: cow              AP:   0.1013  -------
# -------  Class: diningtable      AP:   0.2573  -------
# -------  Class: dog              AP:   0.2056  -------
# -------  Class: horse            AP:   0.4309  -------
# -------  Class: motorbike        AP:   0.2541  -------
# -------  Class: person           AP:   0.6506  -------
# -------  Class: pottedplant      AP:   0.1103  -------
# -------  Class: sheep            AP:   0.1185  -------
# -------  Class: sofa             AP:   0.2255  -------
# -------  Class: train            AP:   0.4040  -------
# -------  Class: tvmonitor        AP:   0.2105  -------
# mAP: 0.2743
# Avg loss: 0.41095498874783515
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.2742894984637714
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.008206803351640701
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.007846635766327381
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.006658654194325209
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.007203542627394199
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.006018964108079672
# -------  Class: aeroplane        AP:   0.5618  -------
# -------  Class: bicycle          AP:   0.2067  -------
# -------  Class: bird             AP:   0.1838  -------
# -------  Class: boat             AP:   0.3419  -------
# -------  Class: bottle           AP:   0.1043  -------
# -------  Class: bus              AP:   0.1270  -------
# -------  Class: car              AP:   0.4725  -------
# -------  Class: cat              AP:   0.2643  -------
# -------  Class: chair            AP:   0.3046  -------
# -------  Class: cow              AP:   0.0893  -------
# -------  Class: diningtable      AP:   0.2648  -------
# -------  Class: dog              AP:   0.2098  -------
# -------  Class: horse            AP:   0.4279  -------
# -------  Class: motorbike        AP:   0.2738  -------
# -------  Class: person           AP:   0.6575  -------
# -------  Class: pottedplant      AP:   0.1186  -------
# -------  Class: sheep            AP:   0.1261  -------
# -------  Class: sofa             AP:   0.2291  -------
# -------  Class: train            AP:   0.4363  -------
# -------  Class: tvmonitor        AP:   0.2293  -------
# mAP: 0.2815
# Avg loss: 0.4643560662865639
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.2814641429586254
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.006008022930473089
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.007135240826755762
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.007334724999964237
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.009483702480793
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.006645625922828913
# -------  Class: aeroplane        AP:   0.5513  -------
# -------  Class: bicycle          AP:   0.2118  -------
# -------  Class: bird             AP:   0.1922  -------
# -------  Class: boat             AP:   0.3262  -------
# -------  Class: bottle           AP:   0.1068  -------
# -------  Class: bus              AP:   0.1247  -------
# -------  Class: car              AP:   0.4808  -------
# -------  Class: cat              AP:   0.2746  -------
# -------  Class: chair            AP:   0.3060  -------
# -------  Class: cow              AP:   0.0959  -------
# -------  Class: diningtable      AP:   0.2607  -------
# -------  Class: dog              AP:   0.1989  -------
# -------  Class: horse            AP:   0.4390  -------
# -------  Class: motorbike        AP:   0.2635  -------
# -------  Class: person           AP:   0.6556  -------
# -------  Class: pottedplant      AP:   0.1342  -------
# -------  Class: sheep            AP:   0.1329  -------
# -------  Class: sofa             AP:   0.2155  -------
# -------  Class: train            AP:   0.4233  -------
# -------  Class: tvmonitor        AP:   0.2134  -------
# mAP: 0.2804
# Avg loss: 0.43785553723573684
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.28036380594403326

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.4177  -------
# -------  Class: bicycle          AP:   0.1827  -------
# -------  Class: bird             AP:   0.2543  -------
# -------  Class: boat             AP:   0.2275  -------
# -------  Class: bottle           AP:   0.0860  -------
# -------  Class: bus              AP:   0.2349  -------
# -------  Class: car              AP:   0.5258  -------
# -------  Class: cat              AP:   0.3399  -------
# -------  Class: chair            AP:   0.3883  -------
# -------  Class: cow              AP:   0.1387  -------
# -------  Class: diningtable      AP:   0.1795  -------
# -------  Class: dog              AP:   0.2324  -------
# -------  Class: horse            AP:   0.4240  -------
# -------  Class: motorbike        AP:   0.3279  -------
# -------  Class: person           AP:   0.7483  -------
# -------  Class: pottedplant      AP:   0.1223  -------
# -------  Class: sheep            AP:   0.2624  -------
# -------  Class: sofa             AP:   0.2619  -------
# -------  Class: train            AP:   0.2877  -------
# -------  Class: tvmonitor        AP:   0.1709  -------
# mAP: 0.2906
# Avg loss: 0.26919157000688404
# 0.29064729471423184

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('/content/gdrive/My Drive/CS747_Assignment2/my_solution.csv', test_aps)
